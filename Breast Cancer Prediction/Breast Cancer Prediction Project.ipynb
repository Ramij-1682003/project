# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv("/kaggle/input/breast-cancer-prediction-project-data/data (1).csv")

# %%
df = df.drop(columns=['id', 'Unnamed: 32'], axis=1)
df['diagnosis'] = df['diagnosis'].map({'M': 0, 'B': 1})

# %%
X = df.drop(columns='diagnosis', axis=1)
Y = df['diagnosis']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=2)

# %%
model = LogisticRegression(max_iter=10000)
model.fit(X_train, Y_train)
# Out:
# LogisticRegression(max_iter=10000)

# %%
train_pred = model.predict(X_train)
train_acc = accuracy_score(Y_train, train_pred)
test_pred = model.predict(X_test)
test_acc = accuracy_score(Y_test, test_pred)

print("✅ Training Accuracy:", train_acc)
print("✅ Testing Accuracy:", test_acc)
# Out:
# ✅ Training Accuracy: 0.9560439560439561
# ✅ Testing Accuracy: 0.9385964912280702

# %%
sample_data = X.iloc[5]
input_data = np.asarray(sample_data).reshape(1, -1)
prediction = model.predict(input_data)

if prediction[0] == 0:
    print("🔴 The Breast Cancer is Malignant")
else:
    print("🟢 The Breast Cancer is Benign")
# Out:
# 🔴 The Breast Cancer is Malignant
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
